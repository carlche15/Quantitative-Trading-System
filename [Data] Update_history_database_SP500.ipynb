# %%
import pyodbc
import pandas as pd
from time import gmtime, strftime
from alpha_vantage.timeseries import TimeSeries
import time
import QuantLib as ql
from utilities.date_utilities import *

# %%
connection = pyodbc.connect('Driver=SQL Server;'
                      'Server=DESKTOP-0CQQR1E\SQLEXPRESS;'
                      'Database=securities_master;'
                      'Trusted_Connection=yes;')
cursor=connection.cursor()
ts = TimeSeries(key='NHXLC1G323WY6E6I', output_format='pandas')

# %%
def check_update(ticker):
    """
    check if a  ticker's history is None or the latest update is performed more (excluding) than 1 data before

    :param ticker:
    :return: -999 for not None, float for business days since last update
    """
    global connection
    proceed_update=False
    
    

    
    data = pd.read_sql_query(
        f"select top 1 *  from securities_hist where ticker='{ticker}' order by eff_date desc", connection)

    if len(data)<1: # first-time update
        return -999
    else:
        current_time = pd.to_datetime(strftime("%Y-%m-%d %H:%M:%S", gmtime()))
        last_updated_time = data["eff_date"][0]
        business_day_since_update = business_day_between(last_updated_time,current_time)
        return business_day_since_update,data["eff_date"][0]

# %%
check_update("A")
# Out:
# (0, Timestamp('2021-06-16 00:00:00'))

# %%
def insert_sec_full(ticker,sec_id,sleep_time=14):
    global connection,cursor,ts
    b_days_since_last_eff, last_eff = check_update(ticker) 

    if b_days_since_last_eff==-999: # security is new, loading all data
        print(f"{ticker} does not exist in the database, fetching full history...")
        data = ts.get_daily_adjusted(ticker, outputsize='full')[0]
        time.sleep(sleep_time)
  
    elif b_days_since_last_eff>=2: # security exists but not up to date
        print(f"{ticker} is {b_days_since_last_eff} days behind, fetching new data...")
        data = ts.get_daily_adjusted(ticker, outputsize='full')[0]
        data = data[:last_eff].iloc[:-1]
        time.sleep(sleep_time)
    else:
        print(f"{ticker} is up to date, no action needed.")
        return 
    
    
    if len(data)>0:
        
        
        for idx in range(len(data)):
            record=data.iloc[idx]
            curr_time=strftime("%Y-%m-%d %H:%M:%S", gmtime())
            insert_str = f"""
            INSERT INTO securities_hist
            (
            sec_id,
            ticker,
            instrument,
            eff_date,
            open_price,
            high_price,
            low_price,
            close_price,
            adj_close_price,
            volume,
            dividend,
            split,
            created_date,
            last_updated_date)
            values (

            '{sec_id}',
            '{ticker}',
            '{'Common Stock'}',
            '{record.name}',
            {record['1. open']},
            {record['2. high']},
            {record['3. low']},
            {record['4. close']},
            {record['5. adjusted close']},
            {record['6. volume']},
            {record['7. dividend amount']},
            {record['8. split coefficient']},
            '{curr_time}',
            '{curr_time}'

            )
            """

            cursor.execute(insert_str)
            connection.commit()
        print(f"{ticker} updated.")

# %%
static_sec_info = pd.read_sql_query("select * from securities", connection)


# update tickers

for  ticker,sec_id in zip(sorted(static_sec_info.ticker.values),sorted(static_sec_info.sec_id.values)):
    try:

        insert_sec_full(ticker,sec_id)
    except Exception:
        print(f"fatal error {ticker}")
        time.sleep(15)
        continue

        


connection.close()
# Out:
# A is up to date, no action needed.
# AAL is 93 days behind, fetching new data...
# AAL updated.
# AAP is 93 days behind, fetching new data...
# AAP updated.
# AAPL is 93 days behind, fetching new data...
# AAPL updated.
# ABBV is 93 days behind, fetching new data...
# ABBV updated.
# ABC is 93 days behind, fetching new data...
# ABC updated.
# ABMD is 93 days behind, fetching new data...
# ABMD updated.
# ABT is 93 days behind, fetching new data...
# ABT updated.
# ACN is 93 days behind, fetching new data...
# ACN updated.
# ADBE is 93 days behind, fetching new data...
# ADBE updated.
# ADI is 93 days behind, fetching new data...
# ADI updated.
# ADM is 93 days behind, fetching new data...
# ADM updated.
# ADP is 93 days behind, fetching new data...
# ADP updated.
# ADSK is 93 days behind, fetching new data...
# ADSK updated.
# AEE is 93 days behind, fetching new data...
# AEE updated.
# AEP is 93 days behind, fetching new data...
# AEP updated.
# AES is 93 days behind, fetching new data...
# AES updated.
# AFL is 93 days behind, fetching new data...
# AFL updated.
# AIG is 93 days behind, fetching new data...
# AIG updated.
# AIZ is 93 days behind, fetching new data...
# AIZ updated.
# AJG is 93 days behind, fetching new data...
# AJG updated.
# AKAM is 93 days behind, fetching new data...
# AKAM updated.
# ALB is 93 days behind, fetching new data...
# ALB updated.
# ALGN is 93 days behind, fetching new data...
# ALGN updated.
# ALK is 93 days behind, fetching new data...
# ALK updated.
# ALL is 93 days behind, fetching new data...
# ALL updated.
# ALLE is 93 days behind, fetching new data...
# ALLE updated.
# ALXN is 93 days behind, fetching new data...
# ALXN updated.
# AMAT is 93 days behind, fetching new data...
# AMAT updated.
# AMCR is 93 days behind, fetching new data...
# AMCR updated.
# AMD is 93 days behind, fetching new data...
# AMD updated.
# AME is 93 days behind, fetching new data...
# AME updated.
# AMGN is 93 days behind, fetching new data...
# AMGN updated.
# AMP is 93 days behind, fetching new data...
# AMP updated.
# AMT is 93 days behind, fetching new data...
# AMT updated.
# AMZN is 93 days behind, fetching new data...
# AMZN updated.
# ANET is 93 days behind, fetching new data...
# ANET updated.
# ANSS is 93 days behind, fetching new data...
# ANSS updated.
# ANTM is 93 days behind, fetching new data...
# ANTM updated.
# AON is 93 days behind, fetching new data...
# AON updated.
# AOS is 93 days behind, fetching new data...
# AOS updated.
# APA is 93 days behind, fetching new data...
# APA updated.
# APD is 93 days behind, fetching new data...
# APD updated.
# APH is 93 days behind, fetching new data...
# APH updated.
# APTV is 93 days behind, fetching new data...
# APTV updated.
# ARE is 93 days behind, fetching new data...
# ARE updated.
# ATO is 93 days behind, fetching new data...
# ATO updated.
# ATVI is 93 days behind, fetching new data...
# ATVI updated.
# AVB is 93 days behind, fetching new data...
# AVB updated.
# AVGO is 93 days behind, fetching new data...
# AVGO updated.
# AVY is 93 days behind, fetching new data...
# AVY updated.
# AWK is 93 days behind, fetching new data...
# AWK updated.
# AXP is 93 days behind, fetching new data...
# AXP updated.
# AZO is 93 days behind, fetching new data...
# AZO updated.
# BA is 93 days behind, fetching new data...
# BA updated.
# BAC is 93 days behind, fetching new data...
# BAC updated.
# BAX is 93 days behind, fetching new data...
# BAX updated.
# BBY is 93 days behind, fetching new data...
# BBY updated.
# BDX is 93 days behind, fetching new data...
# BDX updated.
# BEN is 93 days behind, fetching new data...
# BEN updated.
# fatal error BF.B
# BIIB is 93 days behind, fetching new data...
# BIIB updated.
# BIO is 93 days behind, fetching new data...
# BIO updated.
# BK is 93 days behind, fetching new data...
# BK updated.
# BKNG is 93 days behind, fetching new data...
# BKNG updated.
# BKR is 93 days behind, fetching new data...
# BKR updated.
# BLK is 93 days behind, fetching new data...
# BLK updated.
# BLL is 93 days behind, fetching new data...
# BLL updated.
# BMY is 93 days behind, fetching new data...
# BMY updated.
# BR is 93 days behind, fetching new data...
# BR updated.
# BRK.B is 93 days behind, fetching new data...
# BRK.B updated.
# BSX is 93 days behind, fetching new data...
# BSX updated.
# BWA is 93 days behind, fetching new data...
# BWA updated.
# BXP is 93 days behind, fetching new data...
# BXP updated.
# C is 93 days behind, fetching new data...
# C updated.
# CAG is 93 days behind, fetching new data...
# CAG updated.
# CAH is 93 days behind, fetching new data...
# CAH updated.
# CARR is 93 days behind, fetching new data...
# CARR updated.
# CAT is 93 days behind, fetching new data...
# CAT updated.
# CB is 93 days behind, fetching new data...
# CB updated.
# CBOE is 93 days behind, fetching new data...
# CBOE updated.
# CBRE is 93 days behind, fetching new data...
# CBRE updated.
# CCI is 93 days behind, fetching new data...
# CCI updated.
# CCL is 93 days behind, fetching new data...
# CCL updated.
# CDNS is 93 days behind, fetching new data...
# CDNS updated.
# CDW is 93 days behind, fetching new data...
# CDW updated.
# CE is 93 days behind, fetching new data...
# CE updated.
# CERN is 93 days behind, fetching new data...
# CERN updated.
# CF is 93 days behind, fetching new data...
# CF updated.
# CFG is 93 days behind, fetching new data...
# CFG updated.
# CHD is 93 days behind, fetching new data...
# CHD updated.
# CHRW is 93 days behind, fetching new data...
# CHRW updated.
# CHTR is 93 days behind, fetching new data...
# CHTR updated.
# CI is 93 days behind, fetching new data...
# CI updated.
# CINF is 93 days behind, fetching new data...
# CINF updated.
# CL is 93 days behind, fetching new data...
# CL updated.
# CLX is 93 days behind, fetching new data...
# CLX updated.
# CMA is 93 days behind, fetching new data...
# CMA updated.
# CMCSA is 93 days behind, fetching new data...
# CMCSA updated.
# CME is 93 days behind, fetching new data...
# CME updated.
# CMG is 93 days behind, fetching new data...
# CMG updated.
# CMI is 93 days behind, fetching new data...
# CMI updated.
# CMS is 93 days behind, fetching new data...
# CMS updated.
# CNC is 93 days behind, fetching new data...
# CNC updated.
# CNP is 93 days behind, fetching new data...
# CNP updated.
# COF is 93 days behind, fetching new data...
# COF updated.
# COG is 93 days behind, fetching new data...
# COG updated.
# COO is 93 days behind, fetching new data...
# COO updated.
# COP is 93 days behind, fetching new data...
# COP updated.
# COST is 93 days behind, fetching new data...
# COST updated.
# CPB is 93 days behind, fetching new data...
# CPB updated.
# CPRT is 93 days behind, fetching new data...
# CPRT updated.
# CRM is 93 days behind, fetching new data...
# CRM updated.
# CSCO is 93 days behind, fetching new data...
# CSCO updated.
# CSX is 93 days behind, fetching new data...
# CSX updated.
# CTAS is 93 days behind, fetching new data...
# CTAS updated.
# CTLT is 93 days behind, fetching new data...
# CTLT updated.
# CTSH is 93 days behind, fetching new data...
# CTSH updated.
# CTVA is 93 days behind, fetching new data...
# CTVA updated.
# CTXS is 93 days behind, fetching new data...
# CTXS updated.
# CVS is 93 days behind, fetching new data...
# CVS updated.
# CVX is 93 days behind, fetching new data...
# CVX updated.
# D is 93 days behind, fetching new data...
# D updated.
# DAL is 93 days behind, fetching new data...
# DAL updated.
# DD is 93 days behind, fetching new data...
# DD updated.
# DE is 93 days behind, fetching new data...
# DE updated.
# DFS is 93 days behind, fetching new data...
# DFS updated.
# DG is 93 days behind, fetching new data...
# DG updated.
# DGX is 93 days behind, fetching new data...
# DGX updated.
# DHI is 93 days behind, fetching new data...
# DHI updated.
# DHR is 93 days behind, fetching new data...
# DHR updated.
# DIS is 93 days behind, fetching new data...
# DIS updated.
# DISCA is 93 days behind, fetching new data...
# DISCA updated.
# DISCK is 93 days behind, fetching new data...
# DISCK updated.
# DISH is 93 days behind, fetching new data...
# DISH updated.
# fatal error DLR
# DLTR is 93 days behind, fetching new data...
# DLTR updated.
# DOV is 93 days behind, fetching new data...
# DOV updated.
# DOW is 93 days behind, fetching new data...
# DOW updated.
# DPZ is 93 days behind, fetching new data...
# DPZ updated.
# DRE is 93 days behind, fetching new data...
# DRE updated.
# DRI is 93 days behind, fetching new data...
# DRI updated.
# DTE is 93 days behind, fetching new data...
# DTE updated.
# DUK is 93 days behind, fetching new data...
# DUK updated.
# DVA is 93 days behind, fetching new data...
# DVA updated.
# DVN is 93 days behind, fetching new data...
# DVN updated.
# DXC is 93 days behind, fetching new data...
# DXC updated.
# DXCM is 93 days behind, fetching new data...
# DXCM updated.
# EA is 93 days behind, fetching new data...
# EA updated.
# EBAY is 93 days behind, fetching new data...
# EBAY updated.
# ECL is 93 days behind, fetching new data...
# ECL updated.
# ED is 93 days behind, fetching new data...
# ED updated.
# EFX is 93 days behind, fetching new data...
# EFX updated.
# EIX is 93 days behind, fetching new data...
# EIX updated.
# EL is 93 days behind, fetching new data...
# EL updated.
# EMN is 93 days behind, fetching new data...
# EMN updated.
# EMR is 93 days behind, fetching new data...
# EMR updated.
# ENPH is 93 days behind, fetching new data...
# ENPH updated.
# EOG is 93 days behind, fetching new data...
# EOG updated.
# EQIX is 93 days behind, fetching new data...
# EQIX updated.
# EQR is 93 days behind, fetching new data...
# EQR updated.
# ES is 93 days behind, fetching new data...
# ES updated.
# ESS is 93 days behind, fetching new data...
# ESS updated.
# ETN is 93 days behind, fetching new data...
# ETN updated.
# ETR is 93 days behind, fetching new data...
# ETR updated.
# ETSY is 93 days behind, fetching new data...
# ETSY updated.
# EVRG is 93 days behind, fetching new data...
# EVRG updated.
# EW is 93 days behind, fetching new data...
# EW updated.
# EXC is 93 days behind, fetching new data...
# EXC updated.
# EXPD is 93 days behind, fetching new data...
# EXPD updated.
# EXPE is 93 days behind, fetching new data...
# EXPE updated.
# EXR is 93 days behind, fetching new data...
# EXR updated.
# F is 93 days behind, fetching new data...
# F updated.
# FANG is 93 days behind, fetching new data...
# FANG updated.
# FAST is 93 days behind, fetching new data...
# FAST updated.
# FB is 93 days behind, fetching new data...
# FB updated.
# FBHS is 93 days behind, fetching new data...
# FBHS updated.
# FCX is 93 days behind, fetching new data...
# FCX updated.
# FDX is 93 days behind, fetching new data...
# FDX updated.
# FE is 93 days behind, fetching new data...
# FE updated.
# FFIV is 93 days behind, fetching new data...
# FFIV updated.
# FIS is 93 days behind, fetching new data...
# FIS updated.
# FISV is 93 days behind, fetching new data...
# FISV updated.
# FITB is 93 days behind, fetching new data...
# FITB updated.
# FLIR is 93 days behind, fetching new data...
# FLIR updated.
# FLS is 93 days behind, fetching new data...
# FLS updated.
# FLT is 93 days behind, fetching new data...
# FLT updated.
# FMC is 93 days behind, fetching new data...
# FMC updated.
# FOX is 93 days behind, fetching new data...
# FOX updated.
# FOXA is 93 days behind, fetching new data...
# FOXA updated.
# FRC is 93 days behind, fetching new data...
# FRC updated.
# FRT is 93 days behind, fetching new data...
# FRT updated.
# FTI is 93 days behind, fetching new data...
# FTI updated.
# FTNT is 93 days behind, fetching new data...
# FTNT updated.
# FTV is 93 days behind, fetching new data...
# FTV updated.
# GD is 93 days behind, fetching new data...
# GD updated.
# GE is 93 days behind, fetching new data...
# GE updated.
# GILD is 93 days behind, fetching new data...
# GILD updated.
# GIS is 93 days behind, fetching new data...
# GIS updated.
# GL is 93 days behind, fetching new data...
# GL updated.
# GLW is 93 days behind, fetching new data...
# GLW updated.
# GM is 93 days behind, fetching new data...
# GM updated.
# GOOG is 93 days behind, fetching new data...
# GOOG updated.
# GOOGL is 93 days behind, fetching new data...
# GOOGL updated.
# GPC is 93 days behind, fetching new data...
# GPC updated.
# GPN is 93 days behind, fetching new data...
# GPN updated.
# GPS is 93 days behind, fetching new data...
# GPS updated.
# GRMN is 93 days behind, fetching new data...
# GRMN updated.
# GS is 93 days behind, fetching new data...
# GS updated.
# GWW is 93 days behind, fetching new data...
# GWW updated.
# HAL is 93 days behind, fetching new data...
# HAL updated.
# HAS is 93 days behind, fetching new data...
# HAS updated.
# HBAN is 93 days behind, fetching new data...
# HBAN updated.
# HBI is 93 days behind, fetching new data...
# HBI updated.
# HCA is 93 days behind, fetching new data...
# HCA updated.
# HD is 93 days behind, fetching new data...
# HD updated.
# HES is 93 days behind, fetching new data...
# HES updated.
# HFC is 93 days behind, fetching new data...
# HFC updated.
# HIG is 93 days behind, fetching new data...
# HIG updated.
# HII is 93 days behind, fetching new data...
# HII updated.
# HLT is 93 days behind, fetching new data...
# HLT updated.
# HOLX is 93 days behind, fetching new data...
# HOLX updated.
# HON is 93 days behind, fetching new data...
# HON updated.
# HPE is 93 days behind, fetching new data...
# HPE updated.
# HPQ is 93 days behind, fetching new data...
# HPQ updated.
# HRL is 93 days behind, fetching new data...
# HRL updated.
# HSIC is 93 days behind, fetching new data...
# HSIC updated.
# HST is 93 days behind, fetching new data...
# HST updated.
# HSY is 93 days behind, fetching new data...
# HSY updated.
# HUM is 93 days behind, fetching new data...
# HUM updated.
# HWM is 93 days behind, fetching new data...
# HWM updated.
# IBM is 93 days behind, fetching new data...
# IBM updated.
# ICE is 93 days behind, fetching new data...
# ICE updated.
# IDXX is 93 days behind, fetching new data...
# IDXX updated.
# IEX is 93 days behind, fetching new data...
# IEX updated.
# IFF is 93 days behind, fetching new data...
# IFF updated.
# ILMN is 93 days behind, fetching new data...
# ILMN updated.
# INCY is 93 days behind, fetching new data...
# INCY updated.
# INFO is 93 days behind, fetching new data...
# INFO updated.
# INTC is 93 days behind, fetching new data...
# INTC updated.
# INTU is 93 days behind, fetching new data...
# INTU updated.
# IP is 93 days behind, fetching new data...
# IP updated.
# IPG is 93 days behind, fetching new data...
# IPG updated.
# IPGP is 93 days behind, fetching new data...
# IPGP updated.
# IQV is 93 days behind, fetching new data...
# IQV updated.
# IR is 93 days behind, fetching new data...
# IR updated.
# IRM is 93 days behind, fetching new data...
# IRM updated.
# ISRG is 93 days behind, fetching new data...
# ISRG updated.
# IT is 93 days behind, fetching new data...
# IT updated.
# ITW is 93 days behind, fetching new data...
# ITW updated.
# IVZ is 93 days behind, fetching new data...
# IVZ updated.
# J is 93 days behind, fetching new data...
# J updated.
# JBHT is 93 days behind, fetching new data...
# JBHT updated.
# JCI is 93 days behind, fetching new data...
# JCI updated.
# JKHY is 93 days behind, fetching new data...
# JKHY updated.
# JNJ is 93 days behind, fetching new data...
# JNJ updated.
# JNPR is 93 days behind, fetching new data...
# JNPR updated.
# JPM is 93 days behind, fetching new data...
# JPM updated.
# K is 93 days behind, fetching new data...
# K updated.
# KEY is 93 days behind, fetching new data...
# KEY updated.
# KEYS is 93 days behind, fetching new data...
# KEYS updated.
# KHC is 93 days behind, fetching new data...
# KHC updated.
# KIM is 93 days behind, fetching new data...
# KIM updated.
# KLAC is 93 days behind, fetching new data...
# KLAC updated.
# KMB is 93 days behind, fetching new data...
# KMB updated.
# KMI is 93 days behind, fetching new data...
# KMI updated.
# KMX is 93 days behind, fetching new data...
# KMX updated.
# KO is 93 days behind, fetching new data...
# KO updated.
# KR is 93 days behind, fetching new data...
# KR updated.
# KSU is 93 days behind, fetching new data...
# KSU updated.
# L is 93 days behind, fetching new data...
# L updated.
# LB is 93 days behind, fetching new data...
# LB updated.
# LDOS is 93 days behind, fetching new data...
# LDOS updated.
# LEG is 93 days behind, fetching new data...
# LEG updated.
# LEN is 93 days behind, fetching new data...
# LEN updated.
# LH is 93 days behind, fetching new data...
# LH updated.
# LHX is 93 days behind, fetching new data...
# LHX updated.
# LIN is 93 days behind, fetching new data...
# LIN updated.
# LKQ is 93 days behind, fetching new data...
# LKQ updated.
# LLY is 93 days behind, fetching new data...
# LLY updated.
# LMT is 94 days behind, fetching new data...
# LMT updated.
# LNC is 94 days behind, fetching new data...
# LNC updated.
# LNT is 94 days behind, fetching new data...
# LNT updated.
# LOW is 94 days behind, fetching new data...
# LOW updated.
# LRCX is 94 days behind, fetching new data...
# LRCX updated.
# LUMN is 94 days behind, fetching new data...
# LUMN updated.
# LUV is 94 days behind, fetching new data...
# LUV updated.
# LVS is 94 days behind, fetching new data...
# LVS updated.
# LW is 94 days behind, fetching new data...
# LW updated.
# LYB is 94 days behind, fetching new data...
# LYB updated.
# LYV is 94 days behind, fetching new data...
# LYV updated.
# MA is 94 days behind, fetching new data...
# MA updated.
# MAA is 94 days behind, fetching new data...
# MAA updated.
# MAR is 94 days behind, fetching new data...
# MAR updated.
# MAS is 94 days behind, fetching new data...
# MAS updated.
# MCD is 94 days behind, fetching new data...
# MCD updated.
# MCHP is 94 days behind, fetching new data...
# MCHP updated.
# MCK is 94 days behind, fetching new data...
# MCK updated.
# MCO is 94 days behind, fetching new data...
# MCO updated.
# MDLZ is 94 days behind, fetching new data...
# MDLZ updated.
# MDT is 94 days behind, fetching new data...
# MDT updated.
# MET is 94 days behind, fetching new data...
# MET updated.
# MGM is 94 days behind, fetching new data...
# MGM updated.
# MHK is 94 days behind, fetching new data...
# MHK updated.
# MKC is 94 days behind, fetching new data...
# MKC updated.
# MKTX is 94 days behind, fetching new data...
# MKTX updated.
# MLM is 94 days behind, fetching new data...
# MLM updated.
# MMC is 94 days behind, fetching new data...
# MMC updated.
# MMM is 94 days behind, fetching new data...
# MMM updated.
# MNST is 94 days behind, fetching new data...
# MNST updated.
# MO is 94 days behind, fetching new data...
# MO updated.
# MOS is 94 days behind, fetching new data...
# MOS updated.
# MPC is 94 days behind, fetching new data...
# MPC updated.
# MRK is 94 days behind, fetching new data...
# MRK updated.
# MRO is 94 days behind, fetching new data...
# MRO updated.
# MS is 94 days behind, fetching new data...
# MS updated.
# MSCI is 94 days behind, fetching new data...
# MSCI updated.
# MSFT is 94 days behind, fetching new data...
# MSFT updated.
# MSI is 94 days behind, fetching new data...
# MSI updated.
# MTB is 94 days behind, fetching new data...
# MTB updated.
# MTD is 94 days behind, fetching new data...
# MTD updated.
# MU is 94 days behind, fetching new data...
# MU updated.
# MXIM is 94 days behind, fetching new data...
# MXIM updated.
# NCLH is 94 days behind, fetching new data...
# NCLH updated.
# NDAQ is 94 days behind, fetching new data...
# NDAQ updated.
# NEE is 94 days behind, fetching new data...
# NEE updated.
# NEM is 94 days behind, fetching new data...
# NEM updated.
# NFLX is 94 days behind, fetching new data...
# NFLX updated.
# NI is 94 days behind, fetching new data...
# NI updated.
# NKE is 94 days behind, fetching new data...
# NKE updated.
# NLOK is 94 days behind, fetching new data...
# NLOK updated.
# NLSN is 94 days behind, fetching new data...
# NLSN updated.
# NOC is 94 days behind, fetching new data...
# NOC updated.
# NOV is 94 days behind, fetching new data...
# NOV updated.
# NOW is 94 days behind, fetching new data...
# NOW updated.
# NRG is 94 days behind, fetching new data...
# NRG updated.
# NSC is 94 days behind, fetching new data...
# NSC updated.
# NTAP is 94 days behind, fetching new data...
# NTAP updated.
# NTRS is 94 days behind, fetching new data...
# NTRS updated.
# NUE is 94 days behind, fetching new data...
# NUE updated.
# NVDA is 94 days behind, fetching new data...
# NVDA updated.
# NVR is 94 days behind, fetching new data...
# NVR updated.
# NWL is 94 days behind, fetching new data...
# NWL updated.
# NWS is 94 days behind, fetching new data...
# NWS updated.
# NWSA is 94 days behind, fetching new data...
# NWSA updated.
# O is 94 days behind, fetching new data...
# O updated.
# ODFL is 94 days behind, fetching new data...
# ODFL updated.
# OKE is 94 days behind, fetching new data...
# OKE updated.
# OMC is 94 days behind, fetching new data...
# OMC updated.
# ORCL is 94 days behind, fetching new data...
# ORCL updated.
# ORLY is 94 days behind, fetching new data...
# ORLY updated.
# OTIS is 94 days behind, fetching new data...
# OTIS updated.
# OXY is 94 days behind, fetching new data...
# OXY updated.
# PAYC is 94 days behind, fetching new data...
# PAYC updated.
# PAYX is 94 days behind, fetching new data...
# PAYX updated.
# PBCT is 94 days behind, fetching new data...
# PBCT updated.
# PCAR is 94 days behind, fetching new data...
# PCAR updated.
# PEAK is 94 days behind, fetching new data...
# PEAK updated.
# PEG is 94 days behind, fetching new data...
# PEG updated.
# PEP is 94 days behind, fetching new data...
# PEP updated.
# PFE is 94 days behind, fetching new data...
# PFE updated.
# PFG is 94 days behind, fetching new data...
# PFG updated.
# PG is 94 days behind, fetching new data...
# PG updated.
# PGR is 94 days behind, fetching new data...
# PGR updated.
# PH is 94 days behind, fetching new data...
# PH updated.
# PHM is 94 days behind, fetching new data...
# PHM updated.
# PKG is 94 days behind, fetching new data...
# PKG updated.
# PKI is 94 days behind, fetching new data...
# PKI updated.
# PLD is 94 days behind, fetching new data...
# PLD updated.
# PM is 94 days behind, fetching new data...
# PM updated.
# PNC is 94 days behind, fetching new data...
# PNC updated.
# PNR is 94 days behind, fetching new data...
# PNR updated.
# PNW is 94 days behind, fetching new data...
# PNW updated.
# POOL is 94 days behind, fetching new data...
# POOL updated.
# PPG is 94 days behind, fetching new data...
# PPG updated.
# PPL is 94 days behind, fetching new data...
# PPL updated.
# PRGO is 94 days behind, fetching new data...
# PRGO updated.
# PRU is 94 days behind, fetching new data...
# PRU updated.
# PSA is 94 days behind, fetching new data...
# PSA updated.
# PSX is 94 days behind, fetching new data...
# PSX updated.
# PVH is 94 days behind, fetching new data...
# PVH updated.
# PWR is 94 days behind, fetching new data...
# PWR updated.
# PXD is 94 days behind, fetching new data...
# PXD updated.
# PYPL is 94 days behind, fetching new data...
# PYPL updated.
# QCOM is 94 days behind, fetching new data...
# QCOM updated.
# QRVO is 94 days behind, fetching new data...
# QRVO updated.
# RCL is 94 days behind, fetching new data...
# RCL updated.
# RE is 94 days behind, fetching new data...
# RE updated.
# REG is 94 days behind, fetching new data...
# REG updated.
# REGN is 94 days behind, fetching new data...
# REGN updated.
# RF is 94 days behind, fetching new data...
# RF updated.
# RHI is 94 days behind, fetching new data...
# RHI updated.
# RJF is 94 days behind, fetching new data...
# RJF updated.
# RL is 94 days behind, fetching new data...
# RL updated.
# RMD is 94 days behind, fetching new data...
# RMD updated.
# ROK is 94 days behind, fetching new data...
# ROK updated.
# ROL is 94 days behind, fetching new data...
# ROL updated.
# ROP is 94 days behind, fetching new data...
# ROP updated.
# ROST is 94 days behind, fetching new data...
# ROST updated.
# RSG is 94 days behind, fetching new data...
# RSG updated.
# RTX is 94 days behind, fetching new data...
# RTX updated.
# SBAC is 94 days behind, fetching new data...
# SBAC updated.
# SBUX is 94 days behind, fetching new data...
# SBUX updated.
# SCHW is 94 days behind, fetching new data...
# SCHW updated.
# SEE is 94 days behind, fetching new data...
# SEE updated.
# SHW is 94 days behind, fetching new data...
# SHW updated.
# SIVB is 94 days behind, fetching new data...
# SIVB updated.
# SJM is 94 days behind, fetching new data...
# SJM updated.
# SLB is 94 days behind, fetching new data...
# SLB updated.
# SLG is 94 days behind, fetching new data...
# SLG updated.
# SNA is 94 days behind, fetching new data...
# SNA updated.
# SNPS is 94 days behind, fetching new data...
# SNPS updated.
# SO is 94 days behind, fetching new data...
# SO updated.
# SPG is 94 days behind, fetching new data...
# SPG updated.
# SPGI is 94 days behind, fetching new data...
# SPGI updated.
# SRE is 94 days behind, fetching new data...
# SRE updated.
# STE is 94 days behind, fetching new data...
# STE updated.
# STT is 94 days behind, fetching new data...
# STT updated.
# STX is 94 days behind, fetching new data...
# STX updated.
# STZ is 94 days behind, fetching new data...
# STZ updated.
# SWK is 94 days behind, fetching new data...
# SWK updated.
# SWKS is 94 days behind, fetching new data...
# SWKS updated.
# SYF is 94 days behind, fetching new data...
# SYF updated.
# SYK is 94 days behind, fetching new data...
# SYK updated.
# SYY is 94 days behind, fetching new data...
# SYY updated.
# T is 94 days behind, fetching new data...
# T updated.
# TAP is 94 days behind, fetching new data...
# TAP updated.
# TDG is 94 days behind, fetching new data...
# TDG updated.
# TDY is 94 days behind, fetching new data...
# TDY updated.
# TEL is 94 days behind, fetching new data...
# TEL updated.
# TER is 94 days behind, fetching new data...
# TER updated.
# TFC is 94 days behind, fetching new data...
# TFC updated.
# TFX is 94 days behind, fetching new data...
# TFX updated.
# TGT is 94 days behind, fetching new data...
# TGT updated.
# TJX is 94 days behind, fetching new data...
# TJX updated.
# TMO is 94 days behind, fetching new data...
# TMO updated.
# TMUS is 94 days behind, fetching new data...
# TMUS updated.
# TPR is 94 days behind, fetching new data...
# TPR updated.
# TRMB is 94 days behind, fetching new data...
# TRMB updated.
# TROW is 94 days behind, fetching new data...
# TROW updated.
# TRV is 94 days behind, fetching new data...
# TRV updated.
# TSCO is 94 days behind, fetching new data...
# TSCO updated.
# TSLA is 94 days behind, fetching new data...
# TSLA updated.
# TSN is 94 days behind, fetching new data...
# TSN updated.
# TT is 94 days behind, fetching new data...
# TT updated.
# TTWO is 94 days behind, fetching new data...
# TTWO updated.
# TWTR is 94 days behind, fetching new data...
# TWTR updated.
# TXN is 94 days behind, fetching new data...
# TXN updated.
# TXT is 94 days behind, fetching new data...
# TXT updated.
# TYL is 94 days behind, fetching new data...
# TYL updated.
# UA is 94 days behind, fetching new data...
# UA updated.
# UAA is 94 days behind, fetching new data...
# UAA updated.
# UAL is 94 days behind, fetching new data...
# UAL updated.
# UDR is 94 days behind, fetching new data...
# UDR updated.
# UHS is 94 days behind, fetching new data...
# UHS updated.
# ULTA is 94 days behind, fetching new data...
# ULTA updated.
# UNH is 94 days behind, fetching new data...
# UNH updated.
# UNM is 94 days behind, fetching new data...
# UNM updated.
# UNP is 94 days behind, fetching new data...
# UNP updated.
# UPS is 94 days behind, fetching new data...
# UPS updated.
# URI is 94 days behind, fetching new data...
# URI updated.
# USB is 94 days behind, fetching new data...
# USB updated.
# V is 94 days behind, fetching new data...
# V updated.
# VAR is 94 days behind, fetching new data...
# VAR updated.
# VFC is 94 days behind, fetching new data...
# VFC updated.
# VIAC is 94 days behind, fetching new data...
# VIAC updated.
# VLO is 94 days behind, fetching new data...
# VLO updated.
# VMC is 94 days behind, fetching new data...
# VMC updated.
# VNO is 94 days behind, fetching new data...
# VNO updated.
# VNT is 94 days behind, fetching new data...
# VNT updated.
# VRSK is 94 days behind, fetching new data...
# VRSK updated.
# VRSN is 94 days behind, fetching new data...
# VRSN updated.
# VRTX is 94 days behind, fetching new data...
# VRTX updated.
# VTR is 94 days behind, fetching new data...
# VTR updated.
# VTRS is 94 days behind, fetching new data...
# VTRS updated.
# VZ is 94 days behind, fetching new data...
# VZ updated.
# WAB is 94 days behind, fetching new data...
# WAB updated.
# WAT is 94 days behind, fetching new data...
# WAT updated.
# WBA is 94 days behind, fetching new data...
# WBA updated.
# WDC is 94 days behind, fetching new data...
# WDC updated.
# WEC is 94 days behind, fetching new data...
# WEC updated.
# WELL is 94 days behind, fetching new data...
# WELL updated.
# WFC is 94 days behind, fetching new data...
# WFC updated.
# WHR is 94 days behind, fetching new data...
# WHR updated.
# WLTW is 94 days behind, fetching new data...
# WLTW updated.
# WM is 94 days behind, fetching new data...
# WM updated.
# WMB is 94 days behind, fetching new data...
# WMB updated.
# WMT is 94 days behind, fetching new data...
# WMT updated.
# WRB is 94 days behind, fetching new data...
# WRB updated.
# WRK is 94 days behind, fetching new data...
# WRK updated.
# WST is 94 days behind, fetching new data...
# WST updated.
# WU is 94 days behind, fetching new data...
# WU updated.
# WY is 94 days behind, fetching new data...
# WY updated.
# WYNN is 94 days behind, fetching new data...
# WYNN updated.
# XEL is 94 days behind, fetching new data...
# XEL updated.
# XLNX is 94 days behind, fetching new data...
# XLNX updated.
# XOM is 94 days behind, fetching new data...
# XOM updated.
# XRAY is 94 days behind, fetching new data...
# XRAY updated.
# XRX is 94 days behind, fetching new data...
# XRX updated.
# XYL is 94 days behind, fetching new data...
# XYL updated.
# YUM is 94 days behind, fetching new data...
# YUM updated.
# ZBH is 94 days behind, fetching new data...
# ZBH updated.
# ZBRA is 94 days behind, fetching new data...
# ZBRA updated.
# ZION is 94 days behind, fetching new data...
# fatal error ZION
# ZTS is 94 days behind, fetching new data...
# fatal error ZTS

# %%
connection.close()
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-7-0da231f0229d> in <module>
# ----> 1 connection.close()
#
# ProgrammingError: Attempt to use a closed connection.
