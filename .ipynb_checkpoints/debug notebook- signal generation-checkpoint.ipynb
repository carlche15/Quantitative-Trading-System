# %%
from data_handlers import StockHistDataHandler,ComputeSuite
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
import xarray as xr
data_handler = StockHistDataHandler()

# %%
tickers = data_handler(sql = "select ticker from securities").values.ravel()
ts_range = ["2010-01-03", "2020-01-20"]
selected_tickers = tickers

# %%
all_data = data_handler.get_data(ticker = selected_tickers, invest_horizen = ts_range)

# %%
returns = ComputeSuite.pct_return(all_data)
returns.index = all_data.ticker
returns.columns = np.array(all_data["eff_date"])

# %%
thred = -0.035
selected_return = []
for t in range(returns.values.shape[1]-2)[::2]:

    return_t = returns.values[:,t]
    return_t_next = returns.values[:,t+1]
    signal = return_t<thred
    
    return_t[~signal] = None
    return_t_next[~signal] = None
    selected_return.append(return_t)
    selected_return.append(return_t_next)

    
    
selected_return  = np.array(selected_return).T  
model_return =  pd.DataFrame(selected_return[:,1:][:,::2])

# %%
model_return
# Out:
#      0         1     2     3     4     5        6     7         8     \
# 0     NaN       NaN   NaN   NaN   NaN   NaN      NaN   NaN       NaN
# 1     NaN  0.029472   NaN   NaN   NaN   NaN -0.04028   NaN  0.057608
# 2     NaN       NaN   NaN   NaN   NaN   NaN      NaN   NaN       NaN
# 3     NaN       NaN   NaN   NaN   NaN   NaN      NaN   NaN       NaN
# 4     NaN       NaN   NaN   NaN   NaN   NaN      NaN   NaN       NaN
# ..    ...       ...   ...   ...   ...   ...      ...   ...       ...
# 494   NaN       NaN   NaN   NaN   NaN   NaN      NaN   NaN       NaN
# 495   NaN       NaN   NaN   NaN   NaN   NaN      NaN   NaN       NaN
# 496   NaN       NaN   NaN   NaN   NaN   NaN      NaN   NaN       NaN
# 497   NaN       NaN   NaN   NaN   NaN   NaN      NaN   NaN       NaN
# 498   NaN       NaN   NaN   NaN   NaN   NaN      NaN   NaN       NaN
#
#          9     ...  1253  1254  1255  1256  1257  1258  1259  1260  1261  1262
# ...

# %%
model_return.count(axis=1)
# Out:
# 0       35
# 1      110
# 2       26
# 3       31
# 4       23
#       ...
# 494     14
# 495     16
# 496     39
# 497     49
# 498      3
# Length: 499, dtype: int64

# %%
model_return.mean(axis=1).plot()
# Out:
# <AxesSubplot:>

# %%
ct = model_return.count(axis=1)
rt = model_return.mean(axis=1)

# %%
sns.distplot(ct)
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
sns.distplot(rt[ct>40])
sns.distplot(rt[ct<25],color="g")
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
### old code below

# %%
all_ret = []
select_ret = []
count=[]
for idx, tic in enumerate(selected_tickers):
    ticker = tic
 
    prices =  data_handler(ticker,ts_range,func = ComputeSuite.close_price).values.ravel()
    returns = data_handler(ticker,ts_range,func = ComputeSuite.pct_return).values.ravel()
    thred = -0.035
    vec = []

    for t in range(len(returns)-2)[::2]:
        if (returns[t])<thred:
            vec.append(returns[t])
            vec.append(returns[t+1])
    all_ret.append(np.mean(returns[1:])*100)
    select_ret.append(np.mean(vec[1:][::2])*100)
    count.append(len(vec))
    print(idx+1, tic,len(all_ret))
# Out:
# 1 MMM 1
# 2 ABT 2
# 3 ABBV 3
# 4 ABMD 4
# 5 ACN 5
# 6 ATVI 6
# 7 ADBE 7
# 8 AMD 8
# 9 AAP 9
# 10 AES 10
# 11 AFL 11
# 12 A 12
# 13 APD 13
# 14 AKAM 14
# 15 ALK 15
# 16 ALB 16
# 17 ARE 17
# 18 ALXN 18
# 19 ALGN 19
# 20 ALLE 20
# 21 LNT 21
# 22 ALL 22
# 23 GOOGL 23
# 24 GOOG 24
# 25 MO 25
# 26 AMZN 26
# 27 AMCR 27
# 28 AEE 28
# 29 AAL 29
# 30 AEP 30
# 31 AXP 31
# 32 AIG 32
# 33 AMT 33
# 34 AWK 34
# 35 AMP 35
# 36 ABC 36
# 37 AME 37
# 38 AMGN 38
# 39 APH 39
# 40 ADI 40
# 41 ANSS 41
# 42 ANTM 42
# 43 AON 43
# 44 AOS 44
# 45 APA 45
# 46 AAPL 46
# 47 AMAT 47
# 48 APTV 48
# 49 ADM 49
# 50 ANET 50
# 51 AJG 51
# 52 AIZ 52
# 53 T 53
# 54 ATO 54
# 55 ADSK 55
# 56 ADP 56
# 57 AZO 57
# 58 AVB 58
# 59 AVY 59
# 60 BKR 60
# 61 BLL 61
# 62 BAC 62
# 63 BK 63
# 64 BAX 64
# 65 BDX 65
# 66 BRK.B 66
# 67 BBY 67
# 68 BIO 68
# 69 BIIB 69
# 70 BLK 70
# 71 BA 71
# 72 BKNG 72
# 73 BWA 73
# 74 BXP 74
# 75 BSX 75
# 76 BMY 76
# 77 AVGO 77
# 78 BR 78
# 79 BF.B 79
# 80 CHRW 80
# 81 COG 81
# 82 CDNS 82
# 83 CPB 83
# ...

# %%
np.mean(select_ret)
# Out:
# nan

# %%
summary_df = pd.DataFrame({"ticker":selected_tickers,"return":all_ret,"model":select_ret,"count":count})
summary_df = summary_df[summary_df["return"]>-999]

# %%
summary_df.sort_values(["count"])
# Out:
#     ticker    return     model  count
# 288    LIN  0.095674       NaN      0
# 202    FOX  0.010371  0.858787      2
# 26    AMCR  0.010285  1.116807      2
# 175   EVRG  0.069992  0.124199      4
# 263    JNJ  0.049461  0.704844      4
# ..     ...       ...       ...    ...
# 437   TSLA  0.179646  0.152331    224
# 204    FCX  0.009886 -0.485975    230
# 7      AMD  0.129470  0.175080    232
# 315     MU  0.110491  0.013357    238
# 166   ENPH  0.210557  0.372731    368
#
# [499 rows x 4 columns]

# %%
np.mean(summary_df["return"])
# Out:
# 0.0710353979186048

# %%
np.mean(summary_df["model"])
# Out:
# 0.31462710279927597

# %%
(m[m>-1])
# Out:
# array([ 0.00834361, -0.00763014,  0.01195459, ...,  0.00566286,
#         0.00728442, -0.01585999])

# %%
sns.distplot(all_ret)
sns.distplot(select_ret)

# %%
np.mean(all_ret)/np.std(all_ret)

# %%
np.mean(select_ret)/np.std(select_ret)*np.sqrt(40)
