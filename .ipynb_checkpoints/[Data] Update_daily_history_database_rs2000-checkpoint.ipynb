# %%
import pyodbc
import pandas as pd
from time import gmtime, strftime
from alpha_vantage.timeseries import TimeSeries
import time
import QuantLib as ql
from utilities.date_utilities import *

# %%
connection = pyodbc.connect('Driver=SQL Server;'
                      'Server=DESKTOP-0CQQR1E\SQLEXPRESS;'
                      'Database=securities_master;'
                      'Trusted_Connection=yes;')
cursor=connection.cursor()
ts = TimeSeries(key='NHXLC1G323WY6E6I', output_format='pandas')

# %%
def check_update(ticker):
    """
    check if a  ticker's history is None or the latest update is performed more (excluding) than 1 data before

    :param ticker:
    :return: -999 for not None, float for business days since last update
    """
    global connection
    proceed_update=False
    
    

    
    data = pd.read_sql_query(
        f"select top 1 *  from securities_hist_rs2000 where ticker='{ticker}' order by eff_date desc", connection)

    if len(data)<1: # first-time update
        return -999,None
    else:
        current_time = pd.to_datetime(strftime("%Y-%m-%d %H:%M:%S", gmtime()))
        last_updated_time = data["eff_date"][0]
        business_day_since_update = business_day_between(last_updated_time,current_time)
        return business_day_since_update,data["eff_date"][0]

# %%
def insert_sec_full(ticker,sec_id,sleep_time=14):
    global connection,cursor,ts
    b_days_since_last_eff, last_eff = check_update(ticker) 

    if b_days_since_last_eff==-999: # security is new, loading all data
        print(f"{ticker} does not exist in the database, fetching full history...")
        data = ts.get_daily_adjusted(ticker, outputsize='full')[0]
  
    elif b_days_since_last_eff>=20: # security exists but not up to date
        print(f"{ticker} is {b_days_since_last_eff} days behind, fetching new data...")
        data = ts.get_daily_adjusted(ticker, outputsize='full')[0]
        data = data[:last_eff].iloc[:-1]
        time.sleep(sleep_time)
    else:
        print(f"{ticker} is up to date, no action needed.")
        return 
    time.sleep(sleep_time)
    
    if len(data)>0:
        
        
        for idx in range(len(data)):
            record=data.iloc[idx]
            curr_time=strftime("%Y-%m-%d %H:%M:%S", gmtime())
            insert_str = f"""
            INSERT INTO securities_hist_rs2000
            (
            sec_id,
            ticker,
            instrument,
            eff_date,
            open_price,
            high_price,
            low_price,
            close_price,
            adj_close_price,
            volume,
            dividend,
            split,
            created_date,
            last_updated_date)
            values (

            '{sec_id}',
            '{ticker}',
            '{'Common Stock'}',
            '{record.name}',
            {record['1. open']},
            {record['2. high']},
            {record['3. low']},
            {record['4. close']},
            {record['5. adjusted close']},
            {record['6. volume']},
            {record['7. dividend amount']},
            {record['8. split coefficient']},
            '{curr_time}',
            '{curr_time}'

            )
            """

            cursor.execute(insert_str)
            connection.commit()
        print(f"{ticker} updated.")

# %%
static_sec_info = pd.read_sql_query("select * from securities_rs2000", connection)


# update tickers

for  ticker,sec_id in zip(sorted(static_sec_info.ticker.values),sorted(static_sec_info.sec_id.values)):
    try:

        insert_sec_full(ticker,sec_id)
    except Exception:
        
        print(f"fatal error {ticker}")
        time.sleep(15)
        continue

        


connection.close()
# Out:
# AA is up to date, no action needed.
# AAN does not exist in the database, fetching full history...
# AAN updated.
# AAOI does not exist in the database, fetching full history...
# AAOI updated.
# AAON does not exist in the database, fetching full history...
# AAON updated.
# AAT does not exist in the database, fetching full history...
# AAT updated.
# AAWW does not exist in the database, fetching full history...
# AAWW updated.
# ABCB does not exist in the database, fetching full history...
# ABCB updated.
# ABEO does not exist in the database, fetching full history...
# ABEO updated.
# ABG does not exist in the database, fetching full history...
# ABG updated.
# ABM does not exist in the database, fetching full history...
# ABM updated.
# ABR does not exist in the database, fetching full history...
# ABR updated.
# ABTX does not exist in the database, fetching full history...
# ABTX updated.
# AC does not exist in the database, fetching full history...
# AC updated.
# ACA does not exist in the database, fetching full history...
# ACA updated.
# ACBI does not exist in the database, fetching full history...
# ACBI updated.
# ACCO does not exist in the database, fetching full history...
# ACCO updated.
# ACEL does not exist in the database, fetching full history...
# ACEL updated.
# ACIA does not exist in the database, fetching full history...
# ACIA updated.
# ACIW does not exist in the database, fetching full history...
# ACIW updated.
# ACLS does not exist in the database, fetching full history...
# ACLS updated.
# ACNB does not exist in the database, fetching full history...
# ACNB updated.
# ACRE does not exist in the database, fetching full history...
# ACRE updated.
# ACRX does not exist in the database, fetching full history...
# ACRX updated.
# ACTG does not exist in the database, fetching full history...
# ACTG updated.
# ADC does not exist in the database, fetching full history...
# ADC updated.
# ADES does not exist in the database, fetching full history...
# ADES updated.
# ADMA does not exist in the database, fetching full history...
# ADMA updated.
# ADNT does not exist in the database, fetching full history...
# ADNT updated.
# ADTN does not exist in the database, fetching full history...
# ADTN updated.
# ADUS does not exist in the database, fetching full history...
# ADUS updated.
# ADVM does not exist in the database, fetching full history...
# ADVM updated.
# AE does not exist in the database, fetching full history...
# AE updated.
# AEGN does not exist in the database, fetching full history...
# AEGN updated.
# AEIS does not exist in the database, fetching full history...
# AEIS updated.
# AEL does not exist in the database, fetching full history...
# AEL updated.
# AEO does not exist in the database, fetching full history...
# AEO updated.
# AERI does not exist in the database, fetching full history...
# AERI updated.
# AFIN does not exist in the database, fetching full history...
# AFIN updated.
# AFMD does not exist in the database, fetching full history...
# AFMD updated.
# AGEN does not exist in the database, fetching full history...
# AGEN updated.
# AGFS does not exist in the database, fetching full history...
# AGFS updated.
# AGLE does not exist in the database, fetching full history...
# AGLE updated.
# AGM does not exist in the database, fetching full history...
# AGM updated.
# AGRX does not exist in the database, fetching full history...
# AGRX updated.
# AGS does not exist in the database, fetching full history...
# AGS updated.
# AGTC does not exist in the database, fetching full history...
# AGTC updated.
# AGX does not exist in the database, fetching full history...
# AGX updated.
# AGYS does not exist in the database, fetching full history...
# AGYS updated.
# AHCO does not exist in the database, fetching full history...
# AHCO updated.
# AHH does not exist in the database, fetching full history...
# AHH updated.
# AI does not exist in the database, fetching full history...
# AI updated.
# AIMC does not exist in the database, fetching full history...
# AIMC updated.
# AIMT does not exist in the database, fetching full history...
# AIMT updated.
# AIN does not exist in the database, fetching full history...
# AIN updated.
# AIR does not exist in the database, fetching full history...
# AIR updated.
# AIT does not exist in the database, fetching full history...
# AIT updated.
# AJRD does not exist in the database, fetching full history...
# AJRD updated.
# AJX does not exist in the database, fetching full history...
# AJX updated.
# AKBA does not exist in the database, fetching full history...
# AKBA updated.
# AKCA does not exist in the database, fetching full history...
# AKCA updated.
# AKR does not exist in the database, fetching full history...
# AKR updated.
# AKRO does not exist in the database, fetching full history...
# AKRO updated.
# AKTS does not exist in the database, fetching full history...
# AKTS updated.
# ALBO does not exist in the database, fetching full history...
# ALBO updated.
# ALCO does not exist in the database, fetching full history...
# ALCO updated.
# ALE does not exist in the database, fetching full history...
# ALE updated.
# ALEC does not exist in the database, fetching full history...
# ALEC updated.
# ALEX does not exist in the database, fetching full history...
# ALEX updated.
# ALG does not exist in the database, fetching full history...
# ALG updated.
# ALGT does not exist in the database, fetching full history...
# ALGT updated.
# ALLK does not exist in the database, fetching full history...
# ALLK updated.
# ALLO does not exist in the database, fetching full history...
# ALLO updated.
# ALRM does not exist in the database, fetching full history...
# ALRM updated.
# ALRS does not exist in the database, fetching full history...
# ALRS updated.
# ALSK does not exist in the database, fetching full history...
# ALSK updated.
# ALTG does not exist in the database, fetching full history...
# ALTG updated.
# ALTR does not exist in the database, fetching full history...
# ALTR updated.
# ALX does not exist in the database, fetching full history...
# ALX updated.
# AMAL does not exist in the database, fetching full history...
# AMAL updated.
# AMBA does not exist in the database, fetching full history...
# AMBA updated.
# AMBC does not exist in the database, fetching full history...
# AMBC updated.
# AMC does not exist in the database, fetching full history...
# AMC updated.
# AMCX does not exist in the database, fetching full history...
# AMCX updated.
# AMEH does not exist in the database, fetching full history...
# AMEH updated.
# AMK does not exist in the database, fetching full history...
# AMK updated.
# AMKR does not exist in the database, fetching full history...
# AMKR updated.
# AMN does not exist in the database, fetching full history...
# AMN updated.
# AMNB does not exist in the database, fetching full history...
# AMNB updated.
# AMOT does not exist in the database, fetching full history...
# AMOT updated.
# AMPH does not exist in the database, fetching full history...
# AMPH updated.
# AMRC does not exist in the database, fetching full history...
# AMRC updated.
# AMRK does not exist in the database, fetching full history...
# AMRK updated.
# AMRS does not exist in the database, fetching full history...
# AMRS updated.
# AMRX does not exist in the database, fetching full history...
# AMRX updated.
# AMSC does not exist in the database, fetching full history...
# AMSC updated.
# AMSF does not exist in the database, fetching full history...
# AMSF updated.
# AMSWA does not exist in the database, fetching full history...
# AMSWA updated.
# AMTB does not exist in the database, fetching full history...
# AMTB updated.
# AMWD does not exist in the database, fetching full history...
# AMWD updated.
# ANAB does not exist in the database, fetching full history...
# ANAB updated.
# ANDE does not exist in the database, fetching full history...
# ANDE updated.
# ANF does not exist in the database, fetching full history...
# ANF updated.
# ANGO does not exist in the database, fetching full history...
# ANGO updated.
# ANH does not exist in the database, fetching full history...
# ANH updated.
# ANIK does not exist in the database, fetching full history...
# ANIK updated.
# ANIP does not exist in the database, fetching full history...
# ANIP updated.
# AOSL does not exist in the database, fetching full history...
# AOSL updated.
# APAM does not exist in the database, fetching full history...
# APAM updated.
# APEI does not exist in the database, fetching full history...
# APEI updated.
# APLS does not exist in the database, fetching full history...
# APLS updated.
# APLT does not exist in the database, fetching full history...
# APLT updated.
# APOG does not exist in the database, fetching full history...
# APOG updated.
# APPF does not exist in the database, fetching full history...
# APPF updated.
# APPN does not exist in the database, fetching full history...
# APPN updated.
# APPS does not exist in the database, fetching full history...
# APPS updated.
# APRE does not exist in the database, fetching full history...
# APRE updated.
# APT does not exist in the database, fetching full history...
# APT updated.
# APTS does not exist in the database, fetching full history...
# APTS updated.
# APTX does not exist in the database, fetching full history...
# APTX updated.
# APYX does not exist in the database, fetching full history...
# APYX updated.
# AQST does not exist in the database, fetching full history...
# AQST updated.
# AQUA does not exist in the database, fetching full history...
# AQUA updated.
# AR does not exist in the database, fetching full history...
# AR updated.
# ARA does not exist in the database, fetching full history...
# ARA updated.
# ARAV does not exist in the database, fetching full history...
# ARAV updated.
# ARAY does not exist in the database, fetching full history...
# ARAY updated.
# ARCB does not exist in the database, fetching full history...
# ARCB updated.
# ARCH does not exist in the database, fetching full history...
# ARCH updated.
# ARCT does not exist in the database, fetching full history...
# ARCT updated.
# ARDX does not exist in the database, fetching full history...
# ARDX updated.
# ARGO does not exist in the database, fetching full history...
# ARGO updated.
# ARI does not exist in the database, fetching full history...
# ARI updated.
# ARL does not exist in the database, fetching full history...
# ARL updated.
# ARLO does not exist in the database, fetching full history...
# ARLO updated.
# ARNA does not exist in the database, fetching full history...
# ARNA updated.
# ARNC does not exist in the database, fetching full history...
# ARNC updated.
# AROC does not exist in the database, fetching full history...
# AROC updated.
# AROW does not exist in the database, fetching full history...
# AROW updated.
# ARQT does not exist in the database, fetching full history...
# ARQT updated.
# ARR does not exist in the database, fetching full history...
# ARR updated.
# ARTNA does not exist in the database, fetching full history...
# ARTNA updated.
# ARVN does not exist in the database, fetching full history...
# ARVN updated.
# ARWR does not exist in the database, fetching full history...
# ARWR updated.
# ASC does not exist in the database, fetching full history...
# ASC updated.
# ASGN does not exist in the database, fetching full history...
# ASGN updated.
# ASIX does not exist in the database, fetching full history...
# ASIX updated.
# ASMB does not exist in the database, fetching full history...
# ASMB updated.
# ASPN does not exist in the database, fetching full history...
# ASPN updated.
# ASPS does not exist in the database, fetching full history...
# ASPS updated.
# ASPU does not exist in the database, fetching full history...
# ASPU updated.
# ASTE does not exist in the database, fetching full history...
# ASTE updated.
# ASUR does not exist in the database, fetching full history...
# ASUR updated.
# AT does not exist in the database, fetching full history...
# AT updated.
# ATEC does not exist in the database, fetching full history...
# ATEC updated.
# ATEN does not exist in the database, fetching full history...
# ATEN updated.
# ATEX does not exist in the database, fetching full history...
# ATEX updated.
# ATGE does not exist in the database, fetching full history...
# ATGE updated.
# ATHX does not exist in the database, fetching full history...
# ATHX updated.
# ATI does not exist in the database, fetching full history...
# ATI updated.
# ATKR does not exist in the database, fetching full history...
# ATKR updated.
# ATLC does not exist in the database, fetching full history...
# ATLC updated.
# ATLO does not exist in the database, fetching full history...
# ATLO updated.
# ATNI does not exist in the database, fetching full history...
# ATNI updated.
# ATNX does not exist in the database, fetching full history...
# ATNX updated.
# ATOM does not exist in the database, fetching full history...
# ATOM updated.
# ATRA does not exist in the database, fetching full history...
# ATRA updated.
# ATRC does not exist in the database, fetching full history...
# ATRC updated.
# ATRI does not exist in the database, fetching full history...
# ATRI updated.
# ATRO does not exist in the database, fetching full history...
# ATRO updated.
# ATRS does not exist in the database, fetching full history...
# ATRS updated.
# ATSG does not exist in the database, fetching full history...
# ATSG updated.
# ATXI does not exist in the database, fetching full history...
# ATXI updated.
# AUB does not exist in the database, fetching full history...
# AUB updated.
# AUBN does not exist in the database, fetching full history...
# AUBN updated.
# AVA does not exist in the database, fetching full history...
# AVA updated.
# AVAV does not exist in the database, fetching full history...
# AVAV updated.
# AVCO does not exist in the database, fetching full history...
# AVCO updated.
# AVD does not exist in the database, fetching full history...
# AVD updated.
# AVEO does not exist in the database, fetching full history...
# AVEO updated.
# AVID does not exist in the database, fetching full history...
# AVID updated.
# AVNS does not exist in the database, fetching full history...
# AVNS updated.
# AVRO does not exist in the database, fetching full history...
# AVRO updated.
# AVXL does not exist in the database, fetching full history...
# AVXL updated.
# AVYA does not exist in the database, fetching full history...
# AVYA updated.
# AWR does not exist in the database, fetching full history...
# AWR updated.
# AX does not exist in the database, fetching full history...
# AX updated.
# AXDX does not exist in the database, fetching full history...
# AXDX updated.
# AXGN does not exist in the database, fetching full history...
# AXGN updated.
# AXL does not exist in the database, fetching full history...
# AXL updated.
# AXLA does not exist in the database, fetching full history...
# AXLA updated.
# AXNX does not exist in the database, fetching full history...
# AXNX updated.
# AXSM does not exist in the database, fetching full history...
# AXSM updated.
# AXTI does not exist in the database, fetching full history...
# AXTI updated.
# AYTU does not exist in the database, fetching full history...
# AYTU updated.
# AZZ does not exist in the database, fetching full history...
# AZZ updated.
# B does not exist in the database, fetching full history...
# B updated.
# BANC does not exist in the database, fetching full history...
# BANC updated.
# BAND does not exist in the database, fetching full history...
# BAND updated.
# BANF does not exist in the database, fetching full history...
# BANF updated.
# BANR does not exist in the database, fetching full history...
# BANR updated.
# BATRA does not exist in the database, fetching full history...
# BATRA updated.
# BATRK does not exist in the database, fetching full history...
# BATRK updated.
# BBBY does not exist in the database, fetching full history...
# BBBY updated.
# BBCP does not exist in the database, fetching full history...
# BBCP updated.
# BBIO does not exist in the database, fetching full history...
# BBIO updated.
# BBSI does not exist in the database, fetching full history...
# BBSI updated.
# BCBP does not exist in the database, fetching full history...
# BCBP updated.
# BCC does not exist in the database, fetching full history...
# BCC updated.
# BCEI does not exist in the database, fetching full history...
# BCEI updated.
# BCEL does not exist in the database, fetching full history...
# BCEL updated.
# BCLI does not exist in the database, fetching full history...
# BCLI updated.
# BCML does not exist in the database, fetching full history...
# BCML updated.
# BCO does not exist in the database, fetching full history...
# BCO updated.
# BCOR does not exist in the database, fetching full history...
# BCOR updated.
# BCOV does not exist in the database, fetching full history...
# BCOV updated.
# BCPC does not exist in the database, fetching full history...
# BCPC updated.
# BCRX does not exist in the database, fetching full history...
# BCRX updated.
# BDC does not exist in the database, fetching full history...
# BDC updated.
# BDGE does not exist in the database, fetching full history...
# BDGE updated.
# BDSI does not exist in the database, fetching full history...
# BDSI updated.
# BDTX does not exist in the database, fetching full history...
# BDTX updated.
# BE does not exist in the database, fetching full history...
# BE updated.
# BEAM does not exist in the database, fetching full history...
# BEAM updated.
# BEAT does not exist in the database, fetching full history...
# BEAT updated.
# BECN does not exist in the database, fetching full history...
# BECN updated.
# BELFB does not exist in the database, fetching full history...
# BELFB updated.
# BFC does not exist in the database, fetching full history...
# BFC updated.
# BFIN does not exist in the database, fetching full history...
# BFIN updated.
# BFS does not exist in the database, fetching full history...
# BFS updated.
# BFST does not exist in the database, fetching full history...
# BFST updated.
# BGCP does not exist in the database, fetching full history...
# BGCP updated.
# BGS does not exist in the database, fetching full history...
# BGS updated.
# BGSF does not exist in the database, fetching full history...
# BGSF updated.
# BH does not exist in the database, fetching full history...
# BH updated.
# BHB does not exist in the database, fetching full history...
# BHB updated.
# BHE does not exist in the database, fetching full history...
# BHE updated.
# BHLB does not exist in the database, fetching full history...
# BHLB updated.
# BHVN does not exist in the database, fetching full history...
# BHVN updated.
# BIG does not exist in the database, fetching full history...
# BIG updated.
# BIPC does not exist in the database, fetching full history...
# BIPC updated.
# BJ does not exist in the database, fetching full history...
# BJ updated.
# BJRI does not exist in the database, fetching full history...
# BJRI updated.
# BKD does not exist in the database, fetching full history...
# BKD updated.
# BKE does not exist in the database, fetching full history...
# BKE updated.
# BKH does not exist in the database, fetching full history...
# BKH updated.
# BKU does not exist in the database, fetching full history...
# BKU updated.
# BL does not exist in the database, fetching full history...
# BL updated.
# BLBD does not exist in the database, fetching full history...
# BLBD updated.
# BLD does not exist in the database, fetching full history...
# BLD updated.
# BLDR does not exist in the database, fetching full history...
# BLDR updated.
# BLFS does not exist in the database, fetching full history...
# BLFS updated.
# BLKB does not exist in the database, fetching full history...
# BLKB updated.
# BLMN does not exist in the database, fetching full history...
# BLMN updated.
# BLPH does not exist in the database, fetching full history...
# BLPH updated.
# BLX does not exist in the database, fetching full history...
# BLX updated.
# BMCH does not exist in the database, fetching full history...
# BMCH updated.
# BMI does not exist in the database, fetching full history...
# BMI updated.
# BMRC does not exist in the database, fetching full history...
# BMRC updated.
# BMTC does not exist in the database, fetching full history...
# BMTC updated.
# BNFT does not exist in the database, fetching full history...
# BNFT updated.
# BOCH does not exist in the database, fetching full history...
# BOCH updated.
# BOMN does not exist in the database, fetching full history...
# BOMN updated.
# BOOM does not exist in the database, fetching full history...
# BOOM updated.
# BOOT does not exist in the database, fetching full history...
# BOOT updated.
# BOX does not exist in the database, fetching full history...
# BOX updated.
# BPFH does not exist in the database, fetching full history...
# BPFH updated.
# BPMC does not exist in the database, fetching full history...
# BPMC updated.
# BPRN does not exist in the database, fetching full history...
# BPRN updated.
# BRBR does not exist in the database, fetching full history...
# BRBR updated.
# BRC does not exist in the database, fetching full history...
# BRC updated.
# BRG does not exist in the database, fetching full history...
# BRG updated.
# BRID does not exist in the database, fetching full history...
# BRID updated.
# BRKL does not exist in the database, fetching full history...
# BRKL updated.
# BRKS does not exist in the database, fetching full history...
# BRKS updated.
# BRMK does not exist in the database, fetching full history...
# BRMK updated.
# BRP does not exist in the database, fetching full history...
# BRP updated.
# BRT does not exist in the database, fetching full history...
# BRT updated.
# BRY does not exist in the database, fetching full history...
# BRY updated.
# BSBK does not exist in the database, fetching full history...
# BSBK updated.
# BSGM does not exist in the database, fetching full history...
# BSGM updated.
# BSIG does not exist in the database, fetching full history...
# BSIG updated.
# BSRR does not exist in the database, fetching full history...
# BSRR updated.
# BSTC does not exist in the database, fetching full history...
# BSTC updated.
# BSVN does not exist in the database, fetching full history...
# BSVN updated.
# BTAI does not exist in the database, fetching full history...
# BTAI updated.
# BTU does not exist in the database, fetching full history...
# BTU updated.
# BUSE does not exist in the database, fetching full history...
# BUSE updated.
# BV does not exist in the database, fetching full history...
# BV updated.
# BWB does not exist in the database, fetching full history...
# BWB updated.
# BWFG does not exist in the database, fetching full history...
# BWFG updated.
# BXG does not exist in the database, fetching full history...
# BXG updated.
# BXMT does not exist in the database, fetching full history...
# BXMT updated.
# BXS does not exist in the database, fetching full history...
# BXS updated.
# BY does not exist in the database, fetching full history...
# BY updated.
# BYD does not exist in the database, fetching full history...
# BYD updated.
# BYSI does not exist in the database, fetching full history...
# BYSI updated.
# BZH does not exist in the database, fetching full history...
# BZH updated.
# CABA does not exist in the database, fetching full history...
# CABA updated.
# CAC does not exist in the database, fetching full history...
# CAC updated.
# CADE does not exist in the database, fetching full history...
# CADE updated.
# CAI does not exist in the database, fetching full history...
# CAI updated.
# CAKE does not exist in the database, fetching full history...
# CAKE updated.
# CAL does not exist in the database, fetching full history...
# CAL updated.
# CALA does not exist in the database, fetching full history...
# CALA updated.
# CALB does not exist in the database, fetching full history...
# CALB updated.
# CALM does not exist in the database, fetching full history...
# CALM updated.
# CALX does not exist in the database, fetching full history...
# CALX updated.
# CAMP does not exist in the database, fetching full history...
# CAMP updated.
# CAR does not exist in the database, fetching full history...
# CAR updated.
# CARA does not exist in the database, fetching full history...
# CARA updated.
# CARE does not exist in the database, fetching full history...
# CARE updated.
# CARG does not exist in the database, fetching full history...
# CARG updated.
# CARS does not exist in the database, fetching full history...
# CARS updated.
# CASA does not exist in the database, fetching full history...
# CASA updated.
# CASH does not exist in the database, fetching full history...
# CASH updated.
# CASI does not exist in the database, fetching full history...
# CASI updated.
# CASS does not exist in the database, fetching full history...
# CASS updated.
# CATB does not exist in the database, fetching full history...
# CATB updated.
# CATC does not exist in the database, fetching full history...
# CATC updated.
# CATM does not exist in the database, fetching full history...
# CATM updated.
# CATO does not exist in the database, fetching full history...
# CATO updated.
# CATY does not exist in the database, fetching full history...
# CATY updated.
# CBAN does not exist in the database, fetching full history...
# CBAN updated.
# CBAY does not exist in the database, fetching full history...
# CBAY updated.
# CBB does not exist in the database, fetching full history...
# CBB updated.
# CBFV does not exist in the database, fetching full history...
# CBFV updated.
# CBIO does not exist in the database, fetching full history...
# CBIO updated.
# CBMG does not exist in the database, fetching full history...
# CBMG updated.
# CBNK does not exist in the database, fetching full history...
# CBNK updated.
# CBRL does not exist in the database, fetching full history...
# CBRL updated.
# CBTX does not exist in the database, fetching full history...
# CBTX updated.
# CBU does not exist in the database, fetching full history...
# CBU updated.
# CBZ does not exist in the database, fetching full history...
# CBZ updated.
# CCB does not exist in the database, fetching full history...
# CCB updated.
# CCBG does not exist in the database, fetching full history...
# CCBG updated.
# CCF does not exist in the database, fetching full history...
# CCF updated.
# CCMP does not exist in the database, fetching full history...
# CCMP updated.
# CCNE does not exist in the database, fetching full history...
# CCNE updated.
# CCOI does not exist in the database, fetching full history...
# CCOI updated.
# CCRN does not exist in the database, fetching full history...
# CCRN updated.
# CCS does not exist in the database, fetching full history...
# CCS updated.
# CCXI does not exist in the database, fetching full history...
# CCXI updated.
# CDE does not exist in the database, fetching full history...
# CDE updated.
# CDLX does not exist in the database, fetching full history...
# CDLX updated.
# CDMO does not exist in the database, fetching full history...
# CDMO updated.
# CDNA does not exist in the database, fetching full history...
# CDNA updated.
# CDTX does not exist in the database, fetching full history...
# CDTX updated.
# CDXC does not exist in the database, fetching full history...
# CDXC updated.
# CDXS does not exist in the database, fetching full history...
# CDXS updated.
# CDZI does not exist in the database, fetching full history...
# CDZI updated.
# CECE does not exist in the database, fetching full history...
# CECE updated.
# CEIX does not exist in the database, fetching full history...
# CEIX updated.
# CELH does not exist in the database, fetching full history...
# CELH updated.
# CEMI does not exist in the database, fetching full history...
# CEMI updated.
# CENT does not exist in the database, fetching full history...
# CENT updated.
# CENTA does not exist in the database, fetching full history...
# CENTA updated.
# CENX does not exist in the database, fetching full history...
# CENX updated.
# CERC does not exist in the database, fetching full history...
# CERC updated.
# CERS does not exist in the database, fetching full history...
# CERS updated.
# CEVA does not exist in the database, fetching full history...
# CEVA updated.
# CFB does not exist in the database, fetching full history...
# CFB updated.
# CFFI does not exist in the database, fetching full history...
# CFFI updated.
# CFFN does not exist in the database, fetching full history...
# CFFN updated.
# CFRX does not exist in the database, fetching full history...
# CFRX updated.
# CHCO does not exist in the database, fetching full history...
# CHCO updated.
# CHCT does not exist in the database, fetching full history...
# CHCT updated.
# CHDN does not exist in the database, fetching full history...
# CHDN updated.
# CHEF does not exist in the database, fetching full history...
# CHEF updated.
# CHK does not exist in the database, fetching full history...
# CHK updated.
# CHMA does not exist in the database, fetching full history...
# CHMA updated.
# CHMG does not exist in the database, fetching full history...
# CHMG updated.
# CHMI does not exist in the database, fetching full history...
# CHMI updated.
# CHRS does not exist in the database, fetching full history...
# CHRS updated.
# CHS does not exist in the database, fetching full history...
# CHS updated.
# CHUY does not exist in the database, fetching full history...
# CHUY updated.
# CIA does not exist in the database, fetching full history...
# CIA updated.
# CIM does not exist in the database, fetching full history...
# CIM updated.
# CIO does not exist in the database, fetching full history...
# CIO updated.
# CIR does not exist in the database, fetching full history...
# CIR updated.
# CIT does not exist in the database, fetching full history...
# CIT updated.
# CIVB does not exist in the database, fetching full history...
# CIVB updated.
# CIZN does not exist in the database, fetching full history...
# CIZN updated.
# CKH does not exist in the database, fetching full history...
# CKH updated.
# CKPT does not exist in the database, fetching full history...
# CKPT updated.
# CLAR does not exist in the database, fetching full history...
# CLAR updated.
# CLBK does not exist in the database, fetching full history...
# CLBK updated.
# CLCT does not exist in the database, fetching full history...
# CLCT updated.
# CLDR does not exist in the database, fetching full history...
# CLDR updated.
# CLDT does not exist in the database, fetching full history...
# CLDT updated.
# CLF does not exist in the database, fetching full history...
# CLF updated.
# CLFD does not exist in the database, fetching full history...
# CLFD updated.
# CLI does not exist in the database, fetching full history...
# CLI updated.
# CLNC does not exist in the database, fetching full history...
# CLNC updated.
# CLNE does not exist in the database, fetching full history...
# CLNE updated.
# CLNY does not exist in the database, fetching full history...
# CLNY updated.
# CLPR does not exist in the database, fetching full history...
# CLPR updated.
# CLVS does not exist in the database, fetching full history...
# CLVS updated.
# CLW does not exist in the database, fetching full history...
# CLW updated.
# CLXT does not exist in the database, fetching full history...
# CLXT updated.
# CMBM does not exist in the database, fetching full history...
# CMBM updated.
# CMC does not exist in the database, fetching full history...
# CMC updated.
# CMCL does not exist in the database, fetching full history...
# CMCL updated.
# CMCO does not exist in the database, fetching full history...
# CMCO updated.
# CMCT does not exist in the database, fetching full history...
# CMCT updated.
# CMD does not exist in the database, fetching full history...
# CMD updated.
# CMO does not exist in the database, fetching full history...
# CMO updated.
# CMP does not exist in the database, fetching full history...
# CMP updated.
# CMPR does not exist in the database, fetching full history...
# CMPR updated.
# CMRE does not exist in the database, fetching full history...
# CMRE updated.
# CMRX does not exist in the database, fetching full history...
# CMRX updated.
# CMTL does not exist in the database, fetching full history...
# CMTL updated.
# CNBKA does not exist in the database, fetching full history...
# CNBKA updated.
# CNCE does not exist in the database, fetching full history...
# CNCE updated.
# CNDT does not exist in the database, fetching full history...
# CNDT updated.
# CNK does not exist in the database, fetching full history...
# CNK updated.
# CNMD does not exist in the database, fetching full history...
# CNMD updated.
# CNNE does not exist in the database, fetching full history...
# CNNE updated.
# CNO does not exist in the database, fetching full history...
# CNO updated.
# CNOB does not exist in the database, fetching full history...
# CNOB updated.
# CNR does not exist in the database, fetching full history...
# CNR updated.
# CNS does not exist in the database, fetching full history...
# CNS updated.
# CNSL does not exist in the database, fetching full history...
# CNSL updated.
# CNST does not exist in the database, fetching full history...
# CNST updated.
# CNTG does not exist in the database, fetching full history...
# CNTG updated.
# CNTY does not exist in the database, fetching full history...
# CNTY updated.
# CNX does not exist in the database, fetching full history...
# CNX updated.
# CNXN does not exist in the database, fetching full history...
# CNXN updated.
# CODX does not exist in the database, fetching full history...
# CODX updated.
# COFS does not exist in the database, fetching full history...
# COFS updated.
# COHU does not exist in the database, fetching full history...
# COHU updated.
# COKE does not exist in the database, fetching full history...
# COKE updated.
# COLB does not exist in the database, fetching full history...
# COLB updated.
# COLL does not exist in the database, fetching full history...
# COLL updated.
# CONN does not exist in the database, fetching full history...
# CONN updated.
# COOP does not exist in the database, fetching full history...
# COOP updated.
# CORE does not exist in the database, fetching full history...
# CORE updated.
# CORR does not exist in the database, fetching full history...
# CORR updated.
# CORT does not exist in the database, fetching full history...
# CORT updated.
# COWN does not exist in the database, fetching full history...
# COWN updated.
# CPF does not exist in the database, fetching full history...
# CPF updated.
# CPK does not exist in the database, fetching full history...
# CPK updated.
# CPLG does not exist in the database, fetching full history...
# CPLG updated.
# CPRX does not exist in the database, fetching full history...
# CPRX updated.
# CPS does not exist in the database, fetching full history...
# CPS updated.
# CPSI does not exist in the database, fetching full history...
# CPSI updated.
# CRAI does not exist in the database, fetching full history...
# CRAI updated.
# CRBP does not exist in the database, fetching full history...
# CRBP updated.
# CRC does not exist in the database, fetching full history...
# CRC updated.
# CRD.A does not exist in the database, fetching full history...
# fatal error CRD.A
# CRK does not exist in the database, fetching full history...
# CRK updated.
# CRMD does not exist in the database, fetching full history...
# CRMD updated.
# CRMT does not exist in the database, fetching full history...
# CRMT updated.
# CRNC does not exist in the database, fetching full history...
# CRNC updated.
# CRNX does not exist in the database, fetching full history...
# CRNX updated.
# CROX does not exist in the database, fetching full history...
# CROX updated.
# CRS does not exist in the database, fetching full history...
# CRS updated.
# CRTX does not exist in the database, fetching full history...
# CRTX updated.
# CRVL does not exist in the database, fetching full history...
# CRVL updated.
# CRY does not exist in the database, fetching full history...
# CRY updated.
# CSBR does not exist in the database, fetching full history...
# CSBR updated.
# CSGS does not exist in the database, fetching full history...
# CSGS updated.
# CSII does not exist in the database, fetching full history...
# CSII updated.
# CSOD does not exist in the database, fetching full history...
# CSOD updated.
# CSPR does not exist in the database, fetching full history...
# CSPR updated.
# CSTE does not exist in the database, fetching full history...
# CSTE updated.
# CSTL does not exist in the database, fetching full history...
# CSTL updated.
# CSTR does not exist in the database, fetching full history...
# CSTR updated.
# CSV does not exist in the database, fetching full history...
# CSV updated.
# CSWI does not exist in the database, fetching full history...
# CSWI updated.
# CTB does not exist in the database, fetching full history...
# CTB updated.
# CTBI does not exist in the database, fetching full history...
# CTBI updated.
# CTMX does not exist in the database, fetching full history...
# CTMX updated.
# CTO does not exist in the database, fetching full history...
# CTO updated.
# CTRE does not exist in the database, fetching full history...
# CTRE updated.
# CTRN does not exist in the database, fetching full history...
# CTRN updated.
# CTS does not exist in the database, fetching full history...
# CTS updated.
# CTSO does not exist in the database, fetching full history...
# CTSO updated.
# CTT does not exist in the database, fetching full history...
# CTT updated.
# CUB does not exist in the database, fetching full history...
# CUB updated.
# CUBI does not exist in the database, fetching full history...
# CUBI updated.
# CUE does not exist in the database, fetching full history...
# CUE updated.
# CURO does not exist in the database, fetching full history...
# CURO updated.
# CUTR does not exist in the database, fetching full history...
# CUTR updated.
# CVA does not exist in the database, fetching full history...
# CVA updated.
# CVBF does not exist in the database, fetching full history...
# CVBF updated.
# CVCO does not exist in the database, fetching full history...
# CVCO updated.
# CVCY does not exist in the database, fetching full history...
# CVCY updated.
# CVET does not exist in the database, fetching full history...
# CVET updated.
# CVGW does not exist in the database, fetching full history...
# CVGW updated.
# CVI does not exist in the database, fetching full history...
# CVI updated.
# CVLT does not exist in the database, fetching full history...
# CVLT updated.
# CVLY does not exist in the database, fetching full history...
# CVLY updated.
# CVM does not exist in the database, fetching full history...
# CVM updated.
# CWBR does not exist in the database, fetching full history...
# CWBR updated.
# CWCO does not exist in the database, fetching full history...
# CWCO updated.
# CWEN does not exist in the database, fetching full history...
# CWEN updated.
# CWEN.A does not exist in the database, fetching full history...
# fatal error CWEN.A
# CWH does not exist in the database, fetching full history...
# CWH updated.
# CWK does not exist in the database, fetching full history...
# fatal error CWK
# CWST does not exist in the database, fetching full history...
# fatal error CWST
# CWT does not exist in the database, fetching full history...
# fatal error CWT
# CXP does not exist in the database, fetching full history...
# fatal error CXP
# CXW does not exist in the database, fetching full history...
# fatal error CXW
# CYBE does not exist in the database, fetching full history...
# fatal error CYBE
# CYCN does not exist in the database, fetching full history...
# fatal error CYCN
# CYH does not exist in the database, fetching full history...
# fatal error CYH
# CYRX does not exist in the database, fetching full history...
# fatal error CYRX
# CYTK does not exist in the database, fetching full history...
# fatal error CYTK
# CZNC does not exist in the database, fetching full history...
# fatal error CZNC
# DAKT does not exist in the database, fetching full history...
# fatal error DAKT
# DAN does not exist in the database, fetching full history...
# fatal error DAN
# DAR does not exist in the database, fetching full history...
# fatal error DAR
# DBD does not exist in the database, fetching full history...
# fatal error DBD
# DBI does not exist in the database, fetching full history...
# fatal error DBI
# DCO does not exist in the database, fetching full history...
# fatal error DCO
# DCOM does not exist in the database, fetching full history...
# fatal error DCOM
# DCPH does not exist in the database, fetching full history...
# fatal error DCPH
# DDD does not exist in the database, fetching full history...
# fatal error DDD
# DDS does not exist in the database, fetching full history...
# fatal error DDS
# DEA does not exist in the database, fetching full history...
# fatal error DEA
# DECK does not exist in the database, fetching full history...
# fatal error DECK
# DENN does not exist in the database, fetching full history...
# fatal error DENN
# DFIN does not exist in the database, fetching full history...
# fatal error DFIN
# DGICA does not exist in the database, fetching full history...
# fatal error DGICA
# DGII does not exist in the database, fetching full history...
# fatal error DGII
# DHC does not exist in the database, fetching full history...
# fatal error DHC
# DHIL does not exist in the database, fetching full history...
# fatal error DHIL
# DHT does not exist in the database, fetching full history...
# fatal error DHT
# DHX does not exist in the database, fetching full history...
# fatal error DHX
# DIN does not exist in the database, fetching full history...
# fatal error DIN
# DIOD does not exist in the database, fetching full history...
# fatal error DIOD
# DJCO does not exist in the database, fetching full history...
# fatal error DJCO
# DK does not exist in the database, fetching full history...
# fatal error DK
# DLTH does not exist in the database, fetching full history...
# fatal error DLTH
# DLX does not exist in the database, fetching full history...
# fatal error DLX
# DMRC does not exist in the database, fetching full history...
# fatal error DMRC
# DMTK does not exist in the database, fetching full history...
# fatal error DMTK
# DNLI does not exist in the database, fetching full history...
# fatal error DNLI
# DNOW does not exist in the database, fetching full history...
# fatal error DNOW
# DOC does not exist in the database, fetching full history...
# fatal error DOC
# DOMO does not exist in the database, fetching full history...
# fatal error DOMO
# DOOR does not exist in the database, fetching full history...
# fatal error DOOR
# DORM does not exist in the database, fetching full history...
# fatal error DORM
# DRH does not exist in the database, fetching full history...
# fatal error DRH
# DRNA does not exist in the database, fetching full history...
# fatal error DRNA
# DRQ does not exist in the database, fetching full history...
# fatal error DRQ
# DRRX does not exist in the database, fetching full history...
# fatal error DRRX
# DSKE does not exist in the database, fetching full history...
# fatal error DSKE
# DSPG does not exist in the database, fetching full history...
# fatal error DSPG
# DSSI does not exist in the database, fetching full history...
# fatal error DSSI
# DTIL does not exist in the database, fetching full history...
# fatal error DTIL
# DVAX does not exist in the database, fetching full history...
# fatal error DVAX
# DX does not exist in the database, fetching full history...
# fatal error DX
# DXPE does not exist in the database, fetching full history...
# fatal error DXPE
# DY does not exist in the database, fetching full history...
# fatal error DY
# DYAI does not exist in the database, fetching full history...
# fatal error DYAI
# DZSI does not exist in the database, fetching full history...
# fatal error DZSI
# EARN does not exist in the database, fetching full history...
# fatal error EARN
# EAT does not exist in the database, fetching full history...
# fatal error EAT
# EB does not exist in the database, fetching full history...
# fatal error EB
# EBF does not exist in the database, fetching full history...
# fatal error EBF
# EBIX does not exist in the database, fetching full history...
# fatal error EBIX
# EBMT does not exist in the database, fetching full history...
# fatal error EBMT
# EBS does not exist in the database, fetching full history...
# fatal error EBS
# EBSB does not exist in the database, fetching full history...
# fatal error EBSB
# EBTC does not exist in the database, fetching full history...
# fatal error EBTC
# ECHO does not exist in the database, fetching full history...
# fatal error ECHO
# ECOL does not exist in the database, fetching full history...
# fatal error ECOL
# ECOM does not exist in the database, fetching full history...
# fatal error ECOM
# ECPG does not exist in the database, fetching full history...
# fatal error ECPG
# EDIT does not exist in the database, fetching full history...
# fatal error EDIT
# EEX does not exist in the database, fetching full history...
# fatal error EEX
# EFC does not exist in the database, fetching full history...
# fatal error EFC
# EFSC does not exist in the database, fetching full history...
# fatal error EFSC
# EGAN does not exist in the database, fetching full history...
# fatal error EGAN
# EGBN does not exist in the database, fetching full history...
# fatal error EGBN
# EGHT does not exist in the database, fetching full history...
# fatal error EGHT
# EGLE does not exist in the database, fetching full history...
# fatal error EGLE
# EGOV does not exist in the database, fetching full history...
# fatal error EGOV
# EGP does not exist in the database, fetching full history...
# fatal error EGP
# EGRX does not exist in the database, fetching full history...
# fatal error EGRX
# EHTH does not exist in the database, fetching full history...
# fatal error EHTH
# EIDX does not exist in the database, fetching full history...
# fatal error EIDX
# EIG does not exist in the database, fetching full history...
# fatal error EIG
# EIGI does not exist in the database, fetching full history...
# fatal error EIGI
# EIGR does not exist in the database, fetching full history...
# fatal error EIGR
# ELA does not exist in the database, fetching full history...
# fatal error ELA
# ELF does not exist in the database, fetching full history...
# fatal error ELF
# ELMD does not exist in the database, fetching full history...
# fatal error ELMD
# ELOX does not exist in the database, fetching full history...
# fatal error ELOX
# ELY does not exist in the database, fetching full history...
# fatal error ELY
# EME does not exist in the database, fetching full history...
# fatal error EME
# EML does not exist in the database, fetching full history...
# fatal error EML
# ENDP does not exist in the database, fetching full history...
# fatal error ENDP
# ENOB does not exist in the database, fetching full history...
# fatal error ENOB
# ENS does not exist in the database, fetching full history...
# fatal error ENS
# ENSG does not exist in the database, fetching full history...
# fatal error ENSG
# ENTA does not exist in the database, fetching full history...
# fatal error ENTA
# ENV does not exist in the database, fetching full history...
# fatal error ENV
# ENVA does not exist in the database, fetching full history...
# fatal error ENVA
# ENZ does not exist in the database, fetching full history...
# fatal error ENZ
# EOLS does not exist in the database, fetching full history...
# fatal error EOLS
# EPAC does not exist in the database, fetching full history...
# fatal error EPAC
# EPAY does not exist in the database, fetching full history...
# fatal error EPAY
# EPC does not exist in the database, fetching full history...
# fatal error EPC
# EPM does not exist in the database, fetching full history...
# fatal error EPM
# EPRT does not exist in the database, fetching full history...
# fatal error EPRT
# EPZM does not exist in the database, fetching full history...
# fatal error EPZM
# EQBK does not exist in the database, fetching full history...
# fatal error EQBK
# ERII does not exist in the database, fetching full history...
# fatal error ERII
# ESCA does not exist in the database, fetching full history...
# fatal error ESCA
# ESE does not exist in the database, fetching full history...
# fatal error ESE
# ESGR does not exist in the database, fetching full history...
# fatal error ESGR
# ESNT does not exist in the database, fetching full history...
# fatal error ESNT
# ESPR does not exist in the database, fetching full history...
# fatal error ESPR
# ESQ does not exist in the database, fetching full history...
# fatal error ESQ
# ESSA does not exist in the database, fetching full history...
# fatal error ESSA
# ESTE does not exist in the database, fetching full history...
# fatal error ESTE
# ESXB does not exist in the database, fetching full history...
# fatal error ESXB
# ETH does not exist in the database, fetching full history...
# fatal error ETH
# ETM does not exist in the database, fetching full history...
# fatal error ETM
# ETNB does not exist in the database, fetching full history...
# fatal error ETNB
# ETON does not exist in the database, fetching full history...
# fatal error ETON
# EVBN does not exist in the database, fetching full history...
# fatal error EVBN
# EVC does not exist in the database, fetching full history...
# fatal error EVC
# EVER does not exist in the database, fetching full history...
# fatal error EVER
# EVFM does not exist in the database, fetching full history...
# fatal error EVFM
# EVH does not exist in the database, fetching full history...
# fatal error EVH
# EVI does not exist in the database, fetching full history...
# fatal error EVI
# EVLO does not exist in the database, fetching full history...
# fatal error EVLO
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-a95524b85c62> in <module>
#       8
# ----> 9         insert_sec_full(ticker,sec_id)
#      10     except Exception:
#
# <ipython-input-32-363453cd3696> in insert_sec_full(ticker, sec_id, sleep_time)
#       6         print(f"{ticker} does not exist in the database, fetching full history...")
# ----> 7         data = ts.get_daily_adjusted(ticker, outputsize='full')[0]
#       8
#
# C:\DevelopmentTools\envs\quant\lib\site-packages\alpha_vantage\alphavantage.py in _format_wrapper(self, *args, **kwargs)
#     217         def _format_wrapper(self, *args, **kwargs):
# --> 218             call_response, data_key, meta_data_key = func(
#     219                 self, *args, **kwargs)
#
# C:\DevelopmentTools\envs\quant\lib\site-packages\alpha_vantage\alphavantage.py in _call_wrapper(self, *args, **kwargs)
#     159                 url = '{}{}'.format(url, apikey_parameter)
# --> 160             return self._handle_api_call(url), data_key, meta_data_key
#     161         return _call_wrapper
#
# C:\DevelopmentTools\envs\quant\lib\site-packages\alpha_vantage\alphavantage.py in _handle_api_call(self, url)
#     360             elif "Information" in json_response and self.treat_info_as_error:
# --> 361                 raise ValueError(json_response["Information"])
#     362             elif "Note" in json_response and self.treat_info_as_error:
#
# ValueError: Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-33-a95524b85c62> in <module>
#      11
#      12         print(f"fatal error {ticker}")
# ---> 13         time.sleep(15)
#      14         continue
#      15
#
# KeyboardInterrupt:

# %%
connection.close()
